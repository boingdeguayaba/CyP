# %%
# problema 2.1
N=int(input("dame el numero de sonidos emitidos por el grillo en un minuto: "))
if N>0:
    T=N/4+40
    print(f"la temperatura es: {T} grados Fahrenheit")
else:
    print("el numero tiene que ser mayor a 0")
print("fin del programa")
# Out:
# dame el numero de sonidos emitidos por el grillo en un minuto: 76
# la temperatura es: 59.0 grados Fahrenheit
# fin del programa

# %%
# problema 2.2
P=int(input("dame un numero entero:"))
Q=int(input("dame otro numero entero:"))
EXP=P**3+Q**4-2*P**2
if EXP<680:
    print(P,Q)
print("fin del programa")
# Out:
# dame un numero entero:5
# dame otro numero entero:4
# 5 4
# fin del programa

# %%
# problema 2.3
A=float(input("dame un numero entero:"))
B=float(input("dame otro numero entero:"))
C=float(input("dame un tercer numero entero: "))
DIS=B**2-4*A*C
if DIS>=0:
    X1=((-B)+DIS**0.5)/2*A
    X2=((-B)-DIS**0.5)/2*A
    print(f"raices reales {X1},{X2}")
print("fin del programa")
# Out:
# dame un numero entero:3
# dame otro numero entero:9
# dame un tercer numero entero: 1.5
# raices reales -1.5941191002093418,-25.40588089979066
# fin del programa

# %%
# problema 2.4
MAT=int(input("escribe tu matricula: "))
CAL1=float(input("escribe tu primera calificación:"))
CAL2=float(input("escribe tu segunda calificación:"))
CAL3=float(input("escribe tu tercera calificación:"))
CAL4=float(input("escribe tu cuarta calificación:"))
CAL5=float(input("escribe tu quinta calificación:"))
PRO=(CAL1+CAL2+CAL3+CAL4+CAL5)/5
if PRO>=6:
    print(f"{MAT} tu promedio es {PRO}, calificación aprobatoria")
else:
    print(f"{MAT} tu promedio es {PRO}, calificación reprovatoria")
print("fin del programa")
# Out:
# escribe tu matricula: 94796
# escribe tu primera calificación:9
# escribe tu segunda calificación:6.8
# escribe tu tercera calificación:7.3
# escribe tu cuarta calificación:10
# escribe tu quinta calificación:6.2
# 94796 tu promedio es 7.860000000000001, calificación aprobatoria
# fin del programa

# %%
# problema 2.5
NUM=int(input("dame un numero entero: "))
if NUM>0:
    print(f"numero positivo {NUM}")
else:
    if NUM==0:
        print(f"numero nulo {NUM}")
    else:
        print(f"numero negativo {NUM}")
print("fin del programa")
# Out:
# dame un numero entero: -9
# numero negativo -9
# fin del programa

# %%
# problema 2.6
A=int(input("dame un numero: "))
if A==0:
    print(f"numero nulo {A}")
else:
    if A%2==0:
        print(f"numero par {A}")
    else:
        print(f"numero impar {A}")
print("fin del programa")
# Out:
# dame un numero: 6
# numero par 6
# fin del programa

# %%
# problema 2.7
A=int(input("dame un numero entero:"))
B=int(input("dame otro numero entero:"))
C=int(input("dame un tercer numero entero: "))
if A<C:
    if B<C:
        print("los numeros estan en orden creciente")
    else:
        print("los numeros estan en no estan en orden creciente")
else:
    print("los numeros estan en no estan en orden creciente")
# Out:
# dame un numero entero:7
# dame otro numero entero:8
# dame un tercer numero entero: 9
# los numeros estan en orden creciente

# %%
#problema 2.8
COMPRA=int(input("dame el monto de compra total: "))
if COMPRA<500:
    Pagar==COMPRA
else:
    if COMPRA<=1000:
        PAGAR=COMPRA-(COMPRA*0.05)
    else:
        if COMPRA<=7000:
            PAGAR=COMPRA-(COMPRA*0.11)
        else:
            if COMPRA<=15000:
                PAGAR=COMPRA-(COMPRA*0.18)
            else:
                PAGAR=COMPRA-(COMPRA*0.25)
print(f"total a pagar: {PAGAR}")
# Out:
# dame el monto de compra total3500
# total a pagar: 3115.0

# %%
# problema 2.9
PREBAS=float(input("dame el precio basico del producto"))
if PREBAS>500:
    IMP=20*0.3+(PREBAS-40)*0.5
else:
    if PREBAS>40:
        IMP=20*0.3+(PREBAS-40)*0.4
    else:
        if PREBAS>20:
            IMP=(PREBAS-20)*0.3
        else:
            IMP=0
PRETOT=PREBAS+IMP
print(PREBAS, PRETOT)
# Out:
# dame el precio basico del producto75.68
# 75.68 95.95200000000001

# %%
# problema 2.10
A=float(input("dame un numero :"))
B=float(input("dame otro numero:"))
C=float(input("dame un tercer numero: "))
if A>B:
    if A>C:
        print("A es el mayor")
    else:
        if A==C:
            print("A y C son iguales")
        else:
            print("C es el mayor")
else:
    if A==B:
        if A>C:
            print("A y B son los mayores")
        else:
            if A==C:
                print("A,B,C son iguales")
            else:
                print("C es el mayor")
    else:
        if B>C:
            print("B es el mayor")
        else:
            if B==C:
                print("B y C son los mayores")
            else:
                print("C es el mayor")
print("fin del programa")
# Out:
# dame un numero :6
# dame otro numero:8
# dame un tercer numero: 9
# C es el mayor
# fin del programa

# %%
# problema 2.11
CLAVE=int(input("dame la clave de la zona geografica a la que se llamo"))
NUMIN=int(input("dame la duracion de la llamada en minutos"))
if CLAVE==12:
    COST=NUMIN*2
elif CLAVE==15:
    COST=NUMIN*2.2
elif CLAVE==18:
    COST=NUMIN*4.5
elif CLAVE==19:
    COST=NUMIN*3.5
elif CLAVE==23 or CLAVE==25:
    COST=NUMIN*6
elif CLAVE==29:
    COST=NUMIN*5
print(f"costo total de la llamada: {COST}")
print("fin del programa")
# Out:
# dame la clave de la zona geografica a la que se llamo23
# dame la duracion de la llamada en minutos5
# costo total de la llamada: 30
# fin del programa

# %%
# problema 2.12
SUE=float(input("dame tu sueldo:"))
CATE=int(input("dame tu categoria:"))
HE=int(input("dame tus horas extras: "))
if CATE==1:
    PHE=30
elif CATE==2:
    PHE=38
elif CATE==3:
    PHE=50
elif CATE==4:
    PHE=70
else:
    PHE=0
if HE>=30:
    NSUE=SUE+30*PHE
else:
    NSUE=SUE+HE*PHE
print(NSUE)
print("fin del programa")
# Out:
# dame tu sueldo:1350
# dame tu categoria:1
# dame tus horas extras: 25
# 2100.0
# fin del programa

# %%
# problema 2.13
MAT=int(input("dame tu matricula:"))
CARR=(input("dame tu materia en minusculas y sin acentos:"))
SEM=int(input("dame tu semestre: "))
PROM=float(input("dame tu promedio: "))
if CARR=="econonima":
    if SEM>=6 and PROM>=8.8:
        print(f"{MAT},{CARR}, aceptado")
elif CARR=="Computacion":
    if SEM>6 and PROM>8.5:
        print(f"{MAT},{CARR}, aceptado")
elif CARR=="contablidad" or "administracion":
    if SEM>5 and PROM>8.5:
        print(f"{MAT},{CARR}, aceptado")
print("fin del programa")
# Out:
# dame tu matricula:25900
# dame tu materia en minusculas y sin acentos:contabilidad
# dame tu semestre: 7
# dame tu promedio: 9
# 25900,contabilidad, aceptado
# fin del programa
