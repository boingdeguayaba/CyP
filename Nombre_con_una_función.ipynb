# %%
print("M   M       A       N   N   U   U   EEEE   L" "\nMM MM      A A      NN  N   U   U   E      L" "\nM M M     A   A     N N N   U   U   EEE    L" "\nM   M    AAAAAAA    N  NN   UU UU   E      L" "\nM   M   A       A   N   N    UUU    EEEE   LLLLL")
# Out:
# M   M       A       N   N   U   U   EEEE   L
# MM MM      A A      NN  N   U   U   E      L
# M M M     A   A     N N N   U   U   EEE    L
# M   M    AAAAAAA    N  NN   UU UU   E      L
# M   M   A       A   N   N    UUU    EEEE   LLLLL
