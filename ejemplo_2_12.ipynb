# %%
# ejemplo 2.12
A=int(input("dame un valor entero: "))
B=int(input("dame otro valor diferente al anterior: "))
C=int(input("dame un tercer valor diferente: "))
if A>B:
    if A>C:
        if B>C:
            print(A,B,C)
        else:
            print(C,A,B)
    else:
        print(C,A,B)
else:
    if B>C:
        if A>C:
            print(B,A,C)
        else:
            print(B,C,A)
    else:
        print(C,B,A)
print("fin del programa")
# Out:
# dame un valor entero: 8
# dame otro valor diferente al anterior: 6
# dame un tercer valor diferente: 9
# 9 8 6
# fin del programa
